# %%
#Want to pull out restaurant type, then One-Hot Encode that into df

# %%
import numpy as np
import pandas as pd

# %%
#Import Yelp Dataset
yelp = pd.read_json('business.json', lines=True)

# %%
#Inner merge with Zip Code table to cut down number of rows
zipcodes = pd.read_pickle('./zipcode_neighborhood_table.pkl')

# %%
zipcodes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
# Zip Code        21 non-null int64
# Neighborhood    21 non-null object
# dtypes: int64(1), object(1)
# memory usage: 416.0+ bytes

# %%
yelp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192609 entries, 0 to 192608
# Data columns (total 14 columns):
# address         192609 non-null object
# attributes      163773 non-null object
# business_id     192609 non-null object
# categories      192127 non-null object
# city            192609 non-null object
# hours           147779 non-null object
# is_open         192609 non-null int64
# latitude        192609 non-null float64
# longitude       192609 non-null float64
# name            192609 non-null object
# postal_code     192609 non-null object
# review_count    192609 non-null int64
# stars           192609 non-null float64
# state           192609 non-null object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 20.6+ MB

# %%
set(yelp['state'])
# Out:
# {'AB',
#  'AK',
#  'AL',
#  'AR',
#  'AZ',
#  'BAS',
#  'BC',
#  'CA',
#  'CON',
#  'CT',
#  'DOW',
#  'DUR',
#  'FL',
#  'GA',
#  'IL',
#  'NC',
#  'NE',
#  'NJ',
#  'NM',
#  'NV',
#  'NY',
#  'OH',
#  'ON',
#  'PA',
#  'QC',
#  'SC',
#  'TN',
#  'TX',
#  'UT',
#  'VA',
#  'VT',
#  'WA',
#  'WI',
#  'XGL',
#  'XGM',
#  'XWY'}

# %%
#keep only states with "CA"
yelp.loc[yelp['state'] == 'CA']
# Out:
#                                  address  \
# 19062              7000 N Las Vegas Blvd
# 20237
# 36681                111 N Atlantic Blvd
# 47208
# 54428
# 56948   4372 West Point Loma Blvd, Ste A
# 57583                        Rose Valley
# 68639              32200 Vista Del Monte
# 68990
# 78449                   21170 Beach Blvd
# 81250
# 117552                 16349 N 172nd Ave
# 125576           7120 E Indian School Rd
# 134833
# 137673
# 146690               3541 E Remington Dr
# 151760          16375 Monterey Rd, Ste E
# 159887
# 183435         651 Clairton Blvd, Ste 50
#
#                                                attributes  \
# 19062   {'OutdoorSeating': 'True', 'GoodForKids': 'Fal...
# 20237   {'ByAppointmentOnly': 'True', 'HairSpecializes...
# 36681   {'ByAppointmentOnly': 'True', 'Ambience': '{'r...
# 47208   {'BikeParking': 'True', 'ByAppointmentOnly': '...
# 54428                                                None
# ...

# %%
#Need to convert postal_code to int
yelp['postal_code'] = yelp['postal_code'].apply(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-2073c9875951> in <module>
#       1 #Need to convert postal_code to int
# ----> 2 yelp['postal_code'] = yelp['postal_code'].apply(int)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# ValueError: invalid literal for int() with base 10: 'L5R 3E7'

# %%
yelp.loc[yelp['city'] == 'SanFrancisco']

# %%
yelp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 14 columns):
# address         0 non-null object
# attributes      0 non-null object
# business_id     0 non-null object
# categories      0 non-null object
# city            0 non-null object
# hours           0 non-null object
# is_open         0 non-null int64
# latitude        0 non-null float64
# longitude       0 non-null float64
# name            0 non-null object
# postal_code     0 non-null object
# review_count    0 non-null int64
# stars           0 non-null float64
# state           0 non-null object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 0.0+ bytes
